# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../data/clean_data.csv')
data.head()
# Out:
#    institution                      school_name     city institution_state  \
# 0       134500           Adams State University  Alamosa                CO
# 1       134500           Adams State University  Alamosa                CO
# 2       134800         Colorado School of Mines   Golden                CO
# 3       134800         Colorado School of Mines   Golden                CO
# 4       134900  University of Northern Colorado  Greeley                CO
#
#    degree_level                      degree_type  grad_cohort  \
# 0             3                       Associates            0
# 1             7                          Masters            0
# 2             7                          Masters            0
# 3            17  Doctoral - Research/Scholarship            0
# 4             7                          Masters            0
#
#    grad_cohort_years  y1_p25_earnings  y1_p50_earnings  ...  y5_p50_earnings  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15544 entries, 0 to 15543
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   institution        15544 non-null  int64
#  1   school_name        15544 non-null  object
#  2   city               15544 non-null  object
#  3   institution_state  15544 non-null  object
#  4   degree_level       15544 non-null  int64
#  5   degree_type        15544 non-null  object
#  6   grad_cohort        15544 non-null  int64
#  7   grad_cohort_years  15544 non-null  int64
#  8   y1_p25_earnings    15544 non-null  float64
#  9   y1_p50_earnings    15544 non-null  float64
#  10  y1_p75_earnings    15544 non-null  float64
#  11  y1_grads_earn      15544 non-null  float64
#  12  y5_p25_earnings    15544 non-null  float64
#  13  y5_p50_earnings    15544 non-null  float64
#  14  y5_p75_earnings    15544 non-null  float64
#  15  y5_grads_earn      15544 non-null  float64
# ...

# %%
plt.figure(figsize=(12,8))
sns.stripplot(data=data, x='degree_type', y='y1_p50_earnings', size=3, linewidth=.1)
plt.xticks(rotation=45);

# %%
data.groupby('degree_type')[['y1_p50_earnings','y5_p50_earnings','y10_p50_earnings']].mean()
# Out:
#                                   y1_p50_earnings  y5_p50_earnings  \
# degree_type
# Associates                           33849.415978     45269.036364
# Baccalaureate                        36525.434539     51859.600274
# Certificate 1-2 years                35550.820926     45807.657948
# Certificate < 1 year                 32322.635430     41261.052632
# Doctoral - Professional Practice     70336.421053    112200.005848
# Doctoral - Research/Scholarship      65763.678571     82329.757653
# Masters                              51911.270373     66754.007616
# Post-Bacc Certificate                44021.000000     57860.000000
#
#                                   y10_p50_earnings
# degree_type
# Associates                            53114.113774
# Baccalaureate                         63577.819541
# Certificate 1-2 years                 51812.426559
# Certificate < 1 year                  48183.732991
# Doctoral - Professional Practice     153769.877193
# ...

# %%
data.corr()[['y1_p50_earnings','y5_p50_earnings','y10_p50_earnings']]
# Out:
#                    y1_p50_earnings  y5_p50_earnings  y10_p50_earnings
# institution               0.003442        -0.066831         -0.107317
# degree_level              0.459718         0.539837          0.524407
# grad_cohort               0.030356         0.034780          0.016382
# grad_cohort_years         0.120618         0.027964         -0.029248
# y1_p25_earnings           0.967309         0.842876          0.693326
# y1_p50_earnings           1.000000         0.882978          0.724230
# y1_p75_earnings           0.965040         0.876707          0.723473
# y1_grads_earn             0.133459         0.144688          0.141328
# y5_p25_earnings           0.905742         0.961584          0.854570
# y5_p50_earnings           0.882978         1.000000          0.916140
# y5_p75_earnings           0.826110         0.967958          0.926610
# y5_grads_earn             0.097085         0.119409          0.124152
# ...
